# %% [markdown]
# # CHSH Bell Inequality Lab
#
# Lab #1: Feb 25th 2026
#
# In this lab we explore the CHSH Bell Inequality. Our first experiment is to prepare a Bell state of our choice (in our case we choose the phi+ state |HH>+|VV>). To do this, we calibrate our experimental set-up by tunning the polarization state coming out of our SPDC

# %% [markdown]
# # Lab day 2
# today we recalibrated our set-up and performed a fresh state tomography to make sure we indeed still have our desired $|\Phi^+\rangle$ state.
